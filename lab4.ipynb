# %%
import lab4_gui
import lab4_backend
import tkinter as tk

root = tk.Tk()
lab_gui = lab4_gui.LabGUI(root)
root.mainloop()

# %%
from importlib import reload
lab4_backend = reload(lab4_backend)
lab4_gui = reload(lab4_gui)
